# %% [markdown]
# # CRS FSD Generator — Push to GitHub
# Self-sufficient setup. Fill in your PAT in Cell 1, then run all cells in order.

# %%
# ============================================================
# CELL 1: YOUR DETAILS — fill these in before running
# ============================================================

GITHUB_PAT      = "ghp_YOUR_PAT_HERE"   # paste your PAT here
GITHUB_USERNAME = "sataDientist"
REPO_NAME       = "crs-fsd-generator"
GIT_EMAIL       = "amegoalter@gmail.com"
GIT_NAME        = "Abhinit Sen"
REPO_DESC       = "CRS FSD Generator - free compliance tool by Abhinit Sen"
PRIVATE_REPO    = False   # set True if you want a private repo first

# %%
# ============================================================
# CELL 2: RECREATE ALL PROJECT FILES
# ============================================================
import base64, os, json
from pathlib import Path

BASE = Path(f'/content/{REPO_NAME}')

ENCODED_FILES = {
  "README.md": "...",
  "app.py": "...",
  "data/fi_types.json": "...",
  "kb/jurisdiction_urls.json": "...",
  "kb/jurisdictions/ae.json": "...",
  "kb/jurisdictions/at.json": "...",
  "kb/jurisdictions/au.json": "...",
  "kb/jurisdictions/be.json": "...",
  "kb/jurisdictions/bm.json": "...",
  "kb/jurisdictions/ca.json": "...",
  "kb/jurisdictions/ch.json": "...",
  "kb/jurisdictions/cy.json": "...",
  "kb/jurisdictions/de.json": "...",
  "kb/jurisdictions/dk.json": "...",
  "kb/jurisdictions/es.json": "...",
  "kb/jurisdictions/fi.json": "...",
  "kb/jurisdictions/fr.json": "...",
  "kb/jurisdictions/gb.json": "...",
  "kb/jurisdictions/gg.json": "...",
  "kb/jurisdictions/hk.json": "...",
  "kb/jurisdictions/ie.json": "...",
  "kb/jurisdictions/im.json": "...",
  "kb/jurisdictions/it.json": "...",
  "kb/jurisdictions/je.json": "...",
  "kb/jurisdictions/jp.json": "...",
  "kb/jurisdictions/ky.json": "...",
  "kb/jurisdictions/lu.json": "...",
  "kb/jurisdictions/mt.json": "...",
  "kb/jurisdictions/nl.json": "...",
  "kb/jurisdictions/no.json": "...",
  "kb/jurisdictions/nz.json": "...",
  "kb/jurisdictions/se.json": "...",
  "kb/jurisdictions/sg.json": "...",
  "kb/jurisdictions/vg.json": "...",
  "pytest.ini": "",
  "requirements.txt": "Z3JhZGlvPj00LjQ0LjAKZ3JvcT49MC45LjAKZ29vZ2xlLWdlbmVyYXRpdmVhaT49MC43LjAKcmVxdWVzdHM+PTIuMzEuMApwZGZwbHVtYmVyPj0wLjEwLjAKYmVhdXRpZnVsc291cDQ+PTQuMTIuMApweXRob24tZG9jeD49MS4xLjAK",
  "src/__init__.py": "IyBDUlMgRlNEIEdlbmVyYXRvciAtIHNvdXJjZSBtb2R1bGVzCg==",
  "src/doc_fetcher.py": "...",
  "src/docx_builder.py": "...",
  "src/fsd_generator.py": "...",
  "src/llm_router.py": "...",
  "tests/conftest.py": "...",
  "tests/test_docx.py": "...",
  "tests/test_fetcher.py": "...",
  "tests/test_generator.py": "...",
  "tests/test_integration.py": "...",
  "tests/test_kb.py": "...",
  "tests/test_live.py": "...",
  "tests/test_router.py": "..."
}

print(f'Writing {len(ENCODED_FILES)} files to {BASE} ...')
for rel_path, b64_content in ENCODED_FILES.items():
    target = BASE / rel_path
    target.parent.mkdir(parents=True, exist_ok=True)
    target.write_bytes(base64.b64decode(b64_content))

# Create empty cache dir (needed at runtime)
(BASE / 'cache').mkdir(exist_ok=True)

print('All files written.')
print('Directory structure:')
for p in sorted(BASE.rglob('*')):
    if p.is_file() and '__pycache__' not in str(p):
        print(f'  {p.relative_to(BASE)}')

# %%
# ============================================================
# CELL 3: CREATE GITHUB REPO
# ============================================================
import requests

headers = {
    "Authorization": f"token {GITHUB_PAT}",
    "Accept": "application/vnd.github.v3+json"
}

r = requests.post(
    "https://api.github.com/user/repos",
    json={
        "name": REPO_NAME,
        "description": REPO_DESC,
        "private": PRIVATE_REPO,
        "auto_init": False
    },
    headers=headers
)

if r.status_code == 201:
    print(f"Repo created: {r.json()['html_url']}")
elif r.status_code == 422:
    print("Repo already exists on GitHub — will push to it.")
else:
    print(f"Unexpected response {r.status_code}: {r.text}")
    raise SystemExit("Fix the error above before continuing.")

# %%
# ============================================================
# CELL 4: GIT INIT AND PUSH
# ============================================================
import subprocess, os
from pathlib import Path

REPO_DIR = f'/content/{REPO_NAME}'

def run(cmd, **kw):
    """Run a command, print output, raise on failure."""
    label = ' '.join(cmd[:4])
    result = subprocess.run(cmd, capture_output=True, text=True, cwd=REPO_DIR, **kw)
    status = 'OK' if result.returncode == 0 else 'FAILED'
    print(f'[{status}] {label}')
    if result.stdout.strip():
        print('  stdout:', result.stdout.strip())
    if result.stderr.strip():
        print('  stderr:', result.stderr.strip())
    if result.returncode != 0:
        raise SystemExit(f'Command failed: {label}')
    return result

REMOTE = f'https://{GITHUB_USERNAME}:{GITHUB_PAT}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git'

# Sanity check
print(f'Repo dir exists: {Path(REPO_DIR).exists()}')
print(f'Files in repo dir: {len(list(Path(REPO_DIR).rglob("*")))}')
print()

run(['git', 'init'])
run(['git', 'config', 'user.email', GIT_EMAIL])
run(['git', 'config', 'user.name', GIT_NAME])

# Ensure cache dir is tracked (git ignores empty dirs)
keepfile = Path(REPO_DIR) / 'cache' / '.gitkeep'
keepfile.touch()

run(['git', 'add', '-A'])

# Check what's staged
staged = subprocess.run(['git', 'status', '--short'], capture_output=True, text=True, cwd=REPO_DIR)
print(f'Staged files: {len(staged.stdout.strip().splitlines())}')

run(['git', 'commit', '-m', 'Initial build: CRS FSD Generator'])
run(['git', 'branch', '-M', 'main'])
run(['git', 'remote', 'add', 'origin', REMOTE])
run(['git', 'push', '-u', 'origin', 'main'])

print()
print(f'Done. Repo is live at:')
print(f'  https://github.com/{GITHUB_USERNAME}/{REPO_NAME}')
print()
print('Next steps:')
print('  1. Go to https://huggingface.co/spaces/sataDientist/crs-fsd-generator')
print('  2. Settings > Repository > Link to GitHub repo')
print('  3. Add secrets: GROQ_API_KEY and GEMINI_API_KEY')

# %%
# ============================================================
# CELL 5: OPTIONAL - RUN TESTS BEFORE PUSHING
# Run this BEFORE Cell 4 if you want to verify everything works
# ============================================================
import subprocess, os

os.chdir(f'/content/{REPO_NAME}')

# Install test deps
subprocess.run(['pip', 'install', '-q', '-r', 'requirements.txt', 'pytest', 'pytest-mock'],
               check=True)

# Run unit + integration tests (no API keys needed)
result = subprocess.run(
    ['python', '-m', 'pytest', '-m', 'unit or integration', '-v', '--tb=short'],
    capture_output=False
)

if result.returncode == 0:
    print('All tests passed. Safe to push.')
else:
    print('Some tests failed. Review output above before pushing.')
